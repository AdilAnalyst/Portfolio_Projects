# %% [markdown]
# # Visualization of Clean_data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('E:/Data analysis certificate stuff/Python/titanic_data.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df = df.drop_duplicates()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Sex'] = df['Sex'].apply(lambda x: 1 if x == 'male' else 0)
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int64

# %%
df['Age'] = df['Age'].fillna(np.mean(df['Age']))
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### 1. Counting the Survivors:

# %%
plt.figure(figsize=(10,7))

#ax1 = sns.barplot(data=df, x='Survived', hue='Fare',palette='deep', legend=False )
plt.pie(df['Survived'].value_counts(), labels = ['Not Survived', 'Survived'], colors = ['#4594a4','#9ccbd4'], autopct="%1.1f%%")

plt.title('Total Survivors')

plt.show()

# %% [markdown]
# ### 2. Survivors by Age

# %%
plt.figure(figsize=(8, 6))

ax1 = sns.histplot(data=df, x='Age', hue='Survived',  multiple='stack', palette='deep', kde=False)

ax1.set_title('Survived People by Age')
ax1.set_xlabel('Age')
ax1.set_ylabel('Count')

plt.show()

# %% [markdown]
# The Highlighted one are the survivors and the rest (blue) ones are non-survivors

# %% [markdown]
# ### 3. Count of gender

# %%
plt.figure(figsize=(8, 6))

ax1 = sns.countplot(data=df, x='Sex', hue='Sex', palette='deep', legend=False)

ax1.set_title('People count by Gender')
ax1.set_xlabel('Gender')
ax1.set_ylabel('Count')

new_labels = ['Male', 'Female']
ax1.set_xticklabels(new_labels, rotation=45, fontsize = 10)

plt.show()
# Out:
# C:\Users\Adil Jafferani\AppData\Local\Temp\ipykernel_11468\80244027.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(new_labels, rotation=45, fontsize = 10)

# %% [markdown]
# ### 4. Survivors by gender

# %%
plt.figure(figsize=(8, 6))

ax1 = sns.countplot(data=df, x='Sex', hue='Survived', palette='deep', legend=False)

ax1.set_title('Survivals count by Gender')
ax1.set_xlabel('Sex')
ax1.set_ylabel('Count')

new_labels = ['Male', 'Female']
ax1.set_xticklabels(new_labels, rotation=45, fontsize = 10)

plt.show()
# Out:
# C:\Users\Adil Jafferani\AppData\Local\Temp\ipykernel_11468\2580992804.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(new_labels, rotation=45, fontsize = 10)

# %% [markdown]
# ### 5. Survivors by Class

# %%
plt.figure(figsize=(8, 6))

ax1 = sns.countplot(data=df, x='Pclass', hue='Survived',palette='deep', legend=False)

ax1.set_title('Survivals count by Class')
ax1.set_xlabel('Class')
ax1.set_ylabel('Count')

plt.show()

# %% [markdown]
# ### 6. Pair Plot

# %%
plt.figure(figsize=(8, 6))

Features = ['Sex', 'Age', 'Fare', 'Pclass', 'Survived']
ax1 = sns.pairplot(df[Features], hue = 'Survived', palette= 'deep')

plt.suptitle('Pair Plot', y = 1.02)

plt.show()

# %% [markdown]
# ### 7. Correlation Matrix

# %%
# Calculate the correlation matrix
corr_matrix = df[Features].corr()

# Set up the matplotlib figure
plt.figure(figsize=(24, 7))

# Create a new subplot for the correlation matrix
plt.subplots_adjust(right=0.9)  # Adjust space to make room for the heatmap
cax = plt.axes([1.05, 0.1, 0.2, 0.8])  # Define the position [left, bottom, width, height]

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', cbar=False, ax=cax)
cax.set_title('Correlation Matrix')

plt.show()
